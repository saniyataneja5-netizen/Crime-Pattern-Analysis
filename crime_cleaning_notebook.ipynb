# %% [markdown]
# # Crime Data Cleaning Notebook
# This notebook performs data preprocessing for the crime dataset.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('crime_dataset_india.csv')
df.head()

# %% [markdown]
# ## Dataset Info

# %%
df.shape
df.info()
df.describe()

# %% [markdown]
# ## Check Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# ## Handle Missing Values

# %%
df = df.dropna()

# %% [markdown]
# ## Remove Duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Encoding Categorical Columns

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype('category').cat.codes

df.head()

# %% [markdown]
# ## Save Cleaned Dataset

# %%
df.to_csv('cleaned_crime_data.csv', index=False)
df.head()
